# %%
import lightkurve as lk
from lightkurve import search_targetpixelfile
tpf = search_targetpixelfile('212127137', mission='K2').download()
# Out:
# /anaconda3/lib/python3.6/site-packages/lightkurve/search.py:181: LightkurveWarning: Warning: 3 files available to download. Only the first file has been downloaded. Please use `download_all()` or specify additional criteria (e.g. quarter, campaign, or sector) to limit your search.
#   LightkurveWarning)

# %%
tpf
# Out:
# KeplerTargetPixelFile Object (ID: 212127137)

# %%
# %matplotlib inline
tpf.plot(aperture_mask=tpf.pipeline_mask, mask_color='red')

# %%
import matplotlib.pyplot as plt

user_lc = tpf.to_lightcurve(aperture_mask=tpf.pipeline_mask.astype(bool))
# Clean the light curve
user_lc = user_lc.remove_nans().remove_outliers()
user_lc.plot(marker='o',linestyle='None',markersize=4,color='blue')
plt.ylim(0.9,1.1)
# Out:
# (0.9, 1.1)

# %%
user_lc.errorbar();

# %%
corrector = lk.correctors.SFFCorrector(user_lc)
new_lc_sff = corrector.correct(user_lc.centroid_col,user_lc.centroid_row)

new_lc_sff.plot()
# Out:
# /anaconda3/lib/python3.6/site-packages/scipy/interpolate/interpolate.py:610: RuntimeWarning: divide by zero encountered in true_divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
# /anaconda3/lib/python3.6/site-packages/scipy/interpolate/interpolate.py:613: RuntimeWarning: invalid value encountered in multiply
#   y_new = slope*(x_new - x_lo)[:, None] + y_lo
# /anaconda3/lib/python3.6/site-packages/scipy/interpolate/interpolate.py:610: RuntimeWarning: divide by zero encountered in true_divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
# /anaconda3/lib/python3.6/site-packages/scipy/interpolate/interpolate.py:613: RuntimeWarning: invalid value encountered in multiply
#   y_new = slope*(x_new - x_lo)[:, None] + y_lo
# /anaconda3/lib/python3.6/site-packages/scipy/interpolate/interpolate.py:610: RuntimeWarning: divide by zero encountered in true_divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
# /anaconda3/lib/python3.6/site-packages/scipy/interpolate/interpolate.py:613: RuntimeWarning: invalid value encountered in multiply
#   y_new = slope*(x_new - x_lo)[:, None] + y_lo
# /anaconda3/lib/python3.6/site-packages/scipy/interpolate/interpolate.py:610: RuntimeWarning: divide by zero encountered in true_divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
# /anaconda3/lib/python3.6/site-packages/scipy/interpolate/interpolate.py:613: RuntimeWarning: invalid value encountered in multiply
#   y_new = slope*(x_new - x_lo)[:, None] + y_lo
# /anaconda3/lib/python3.6/site-packages/scipy/interpolate/interpolate.py:610: RuntimeWarning: divide by zero encountered in true_divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
# /anaconda3/lib/python3.6/site-packages/scipy/interpolate/interpolate.py:613: RuntimeWarning: invalid value encountered in multiply
#   y_new = slope*(x_new - x_lo)[:, None] + y_lo
# /anaconda3/lib/python3.6/site-packages/scipy/interpolate/interpolate.py:610: RuntimeWarning: divide by zero encountered in true_divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
# /anaconda3/lib/python3.6/site-packages/scipy/interpolate/interpolate.py:613: RuntimeWarning: invalid value encountered in multiply
#   y_new = slope*(x_new - x_lo)[:, None] + y_lo
# /anaconda3/lib/python3.6/site-packages/scipy/interpolate/interpolate.py:610: RuntimeWarning: divide by zero encountered in true_divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
# /anaconda3/lib/python3.6/site-packages/scipy/interpolate/interpolate.py:613: RuntimeWarning: invalid value encountered in multiply
#   y_new = slope*(x_new - x_lo)[:, None] + y_lo
# /anaconda3/lib/python3.6/site-packages/scipy/interpolate/interpolate.py:610: RuntimeWarning: divide by zero encountered in true_divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
# /anaconda3/lib/python3.6/site-packages/scipy/interpolate/interpolate.py:613: RuntimeWarning: invalid value encountered in multiply
#   y_new = slope*(x_new - x_lo)[:, None] + y_lo
# /anaconda3/lib/python3.6/site-packages/scipy/interpolate/interpolate.py:610: RuntimeWarning: divide by zero encountered in true_divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
# /anaconda3/lib/python3.6/site-packages/scipy/interpolate/interpolate.py:613: RuntimeWarning: invalid value encountered in multiply
#   y_new = slope*(x_new - x_lo)[:, None] + y_lo
# /anaconda3/lib/python3.6/site-packages/scipy/interpolate/interpolate.py:610: RuntimeWarning: divide by zero encountered in true_divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
# /anaconda3/lib/python3.6/site-packages/scipy/interpolate/interpolate.py:613: RuntimeWarning: invalid value encountered in multiply
#   y_new = slope*(x_new - x_lo)[:, None] + y_lo
# WARNING: Input data contains invalid values (NaNs or infs), which were automatically clipped. [astropy.stats.sigma_clipping]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-878a8484a6f6> in <module>
#       1 corrector = lk.correctors.SFFCorrector(user_lc)
# ----> 2 new_lc_sff = corrector.correct(user_lc.centroid_col,user_lc.centroid_row)
#       3
#       4 new_lc_sff.plot()
#
# /anaconda3/lib/python3.6/site-packages/lightkurve/correctors.py in correct(self, centroid_col, centroid_row, polyorder, niters, bins, windows, sigma_1, sigma_2, restore_trend)
#     371             tempflux = np.asarray([item for sublist in flux for item in sublist])
#     372             flux_outliers = sigma_clip(data=tempflux, sigma=sigma_1).mask
# --> 373             self.bspline = self.fit_bspline(new_lc.time[~flux_outliers], tempflux[~flux_outliers])
#     374
#     375             # The SFF algorithm is going to be run on each window independently
#
# /anaconda3/lib/python3.6/site-packages/lightkurve/correctors.py in fit_bspline(self, time, flux, knotspacing)
#     484         """Returns a `scipy.interpolate.BSpline` object to interpolate flux as a function of time."""
#     485         # By default, bspline knots are placed 1.5 days apart
# --> 486         knots = np.arange(time[0], time[-1], knotspacing)
#     487
#     488         # If the light curve has breaks larger than the spacing between knots,
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
pg_sff = new_lc_sff.to_periodogram(oversample_factor=1)
pg_sff.plot()

# %%
pg_sff.plot(view='period', scale='log')

# %%
period = pg_sff.period_at_max_power
print('Best period: {}'.format(period))
new_lc_sff.fold(period.value).scatter();
plt.ylim(0.9,1.1)

# %%
period = pg_sff.period_at_max_power * 4
print('Best period: {}'.format(period))
new_lc_sff.fold(period.value).scatter();

# %%
import astropy.units as u
pg_sff = new_lc_sff.to_periodogram(minimum_period=0.9*u.day, maximum_period=1.2*u.day, oversample_factor=10)

# %%
period = pg_sff.period_at_max_power
print('Best period: {}'.format(period))
new_lc_sff.fold(period.value).scatter();
